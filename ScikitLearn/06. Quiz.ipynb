# %% [markdown]
# # Quiz

# %% [markdown]
# ### 어느 결혼식장에서 피로연의 식수 인원을 올바르게 예측하지 못하여 버려지는 음식으로 고민이 많고 합니다. 현재까지 진행된 결혼식에 대한 결혼식 참석 인원과 그 중에서 식사를 하는 인원의 데이터가 제공될 때, 아래 각 문항에 대한 코드를 작성하시오.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### 1) QuizData.csv 파일로부터 데이터를 읽어와서 결혼식 참석 인원(total), 식수 인원(reception)을 각각의 변수로 저장하시오.

# %%
dataset = pd.read_csv('QuizData.csv')
dataset[:5]
# Out:
#    total  reception
# 0    118         62
# 1    253        148
# 2    320        201
# 3     94         80
# 4    155         92

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### 2) 전체 데이터를 훈련 세트와 테스트 세트로 분리하시오. 이때 비율은 75:25 으로 합니다.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# ### 3) 훈련 세트를 이용하여 단순 선형 회귀 (Simple Linear Regression) 모델을 생성하시오.

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 4) 데이터 시각화 (훈련 세트) 코드를 작성하시오.

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title('reception prediction') # 제목
plt.xlabel('total') #X 축 이름
plt.ylabel('reception') #Y축 이름
plt.show()

# %% [markdown]
# ### 5) 데이터 시각화 (테스트 세트) 코드를 작성하시오.

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title('reception prediction') # 제목
plt.xlabel('total') #X 축 이름
plt.ylabel('reception') #Y축 이름
plt.show()

# %% [markdown]
# ### 6) 훈련 세트, 테스트 세트에 대해 각각 모델 평가 점수를 구하시오.

# %%
reg.score(X_train, y_train)
# Out:
# 0.8707088403321211

# %%
reg.score(X_test, y_test)
# Out:
# 0.8634953212566615

# %% [markdown]
# ### 7) 결혼식 참석 인원이 300명일 때 예상되는 식수 인원을 구하시오.

# %%
total = 300 # 결혼식 참석 인원
y_pred = reg.predict([[total]])
print(f"결혼식 참석 인원 {total} 명에 대한 예상 식수 인원은 {np.around(y_pred[0]).astype(int)} 명입니다.")
# Out:
# 결혼식 참석 인원 300 명에 대한 예상 식수 인원은 177 명입니다.
